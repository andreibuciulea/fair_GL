# %% [markdown]
# ### Vary dimension $p$
# Vary the number of nodes $p$ and observe the error, bias, and time to run.
# The number of samples scales with $(p+s) \log p$ for $s$ denoting the sparsity of the precision matrix.

# %%
from utils import *
from opt import *
from time import perf_counter
import pickle

from joblib import Parallel, delayed
import os

from sklearn.covariance import graphical_lasso

SEED = 10
SAVE = True
PATH = './results/vardim/'
N_CPUS = os.cpu_count() // 2
np.random.seed(SEED)

os.environ["OMP_NUM_THREADS"] = str(N_CPUS)

# %% [markdown]
# ## Auxiliary functions

# %%
def create_data(p, n, mean_deg, group_prop, psd_fact=.05, weighted_edges=True, w_range=(.5, 1)):
    Z = create_Z(p, group_prop)

    # Create graph
    edge_prob = mean_deg/(p-1)
    A_true = generate_connected_er(p, edge_prob)

    if weighted_edges:
        weights = np.random.uniform(w_range[0], w_range[1], size=A_true.shape)
        weights = np.tril(weights)
        A_true = (weights + weights.T) * A_true

    # Precision matrix as loaded adjacency
    max_eigenval = np.abs(la.eigvalsh(A_true)[0])
    Theta = (max_eigenval + psd_fact) * np.eye(p) + A_true

    # Create signals
    Sigma = la.inv(Theta)
    X = np.random.multivariate_normal(np.zeros(p), Sigma, n)
    Sigma_hat = X.T@X/n

    return Sigma_hat, Theta, Z


def compute_metric_err(Thetas_est, Thetas_true, n_exps, Zs=None, thr=.2, metric_type='err'):
    n_graphs = len(Thetas_est)
    n_samples = len(Thetas_est[0])

    metric = np.zeros((n_graphs, n_samples, n_exps))
    for i, Thetas in enumerate(Thetas_true):
        for j, Theta in enumerate(Thetas):
            p = Theta.shape[0]
            Theta_od = Theta*(1-np.eye(p))
            for k in range(n_exps):
            
                Theta_exps_od = Thetas_est[i][j][k]*(1-np.eye(p))

                if metric_type == 'err':
                    metric[i,j,k] = compute_frob_err(Theta_exps_od, Theta_od)
                elif metric_type == 'err-v2':
                    metric[i,j,k] = compute_frob_err(Theta_exps_od, Theta_od, pre_norm=True)
                elif metric_type == 'f1':
                    metric[i,j,k] = compute_f1_score(Theta_exps_od, Theta_od, thr)
                elif metric_type == 'bias':
                    mean_Theta = np.mean(mat2lowtri(np.abs(Theta_exps_od)))
                    metric[i,j,k] = compute_dp2(Theta_exps_od, Zs[i][j]) / mean_Theta if mean_Theta else 0
                elif metric_type == 'sqrt-bias':
                    mean_Theta = np.mean(mat2lowtri(np.abs(Theta_exps_od)))
                    metric[i,j,k] = np.sqrt(compute_dp2(Theta_exps_od, Zs[i][j])) / mean_Theta if mean_Theta else 0
                else:
                    raise ValueError('Unknown metric.')

    return metric

def plot_results(x_range, err, exps, y_label='Error', plot_f='semilogx', plt_args={},
                 save=False, file_name=None):

    mean_err = np.mean(err, axis=0)
    fig = plt.figure(figsize=(5,4))
    ax = fig.subplots()

    for i, exp in enumerate(exps):
        getattr(ax, plot_f)(x_range, mean_err[:,i], exp['fmt'], **plt_args, label=exp['leg'])

    ax.set_xlabel('Number of nodes')
    ax.set_ylabel(y_label)
    ax.legend()
    ax.grid(True)
    fig.tight_layout()

    if save and file_name:
        plt.savefig(file_name)
        print('Fig save as:', file_name)


def plot_err_bias_results(err, bias, exps, plot_lines=True, x_label='Error',
                          y_label='Bias', save=False, file_name=None):
    mean_err = np.mean(err, axis=0)
    mean_bias = np.mean(bias, axis=0)

    fig = plt.figure(figsize=(5,4))
    ax = fig.subplots()
    for i, exp in enumerate(exps):
        if plot_lines:
            ax.loglog(mean_err[:,i], mean_bias[:,i], exp['fmt'], label=exp['leg'])
        else:
            ax.loglog(mean_err[:,i], mean_bias[:,i], exp['fmt'][0], label=exp['leg'],
                      linestyle='None')
    # Adding labels and title
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.legend()
    ax.grid(True)
    fig.tight_layout()

    if save and file_name:
        plt.savefig(file_name)
        print('Fig save as:', file_name)

def get_n_samples(n_nodes, n_edges, times=1):
    return int((n_nodes + n_edges)*np.log(n_nodes) * times)

def get_mu1_value(n_nodes, n_samples, times=1):
    return np.sqrt(np.log(n_nodes) / n_samples) * times 

def get_mu2_value(n_nodes, times=1):
    return times * (n_nodes - 1)**2

def run_exp(g, dim_range, data_p, exps, verb=False):
    Thetas_true = []
    Thetas_est = []
    Zs = []
    runingtimes = np.zeros((len(dim_range), len(exps)))
    for i, p in enumerate(dim_range):

        print('Graph', g+1, 'Number of nodes:', p)

        n = get_n_samples(p, p*data_p['mean_deg'])
        Sigma_hat, Theta, Z = create_data(p, n, **data_p)
        Thetas_true.append(Theta)
        Zs.append(Z)

        Theta_od = Theta*(1-np.eye(p))

        Thetas_est_e = np.zeros((len(exps), p,p))
        for j, exp in enumerate(exps):
            args = exp['args'].copy()

            t_init = perf_counter()
            if exp['model'] == 'glasso':
                args['alpha'] = get_mu1_value(p, n, args['alpha'] )
                _, Theta_est = graphical_lasso(Sigma_hat, **args)
            elif exp['model'] == 'fair_flasso':
                args['mu1'] = get_mu1_value(p, n, args['mu1'] )
                args['mu2'] = get_mu2_value(p, args['mu2'] ) 
                Theta_est = FairGLASSO_fista(Sigma_hat, Z=Z, **args)
            
            runingtimes[i,j] = perf_counter() - t_init
            Thetas_est_e[j] = Theta_est

            Theta_est_od = Theta_est*(1-np.eye(p))
            err = compute_frob_err(Theta_est_od, Theta_od)
            bias = compute_dp2(Theta_est, Z) / np.mean(mat2lowtri(np.abs(Theta_est_od))) if np.mean(mat2lowtri(np.abs(Theta_est_od))) else 0
            bias_v2 = compute_dp2(Theta_est_od, Z) / np.mean(mat2lowtri(np.abs(Theta_est_od))) if np.mean(mat2lowtri(np.abs(Theta_est_od))) else 0

            if verb:
                print(f'\t{exp["leg"]}: Err: {err:.4f} | Bias: {bias:.5f} | Bias v2: {bias_v2:.5f} | Time: {runingtimes[i,j]:.4f}')

        Thetas_est.append(Thetas_est_e)
        
    return Thetas_est, Thetas_true, runingtimes, Zs

def save_files(prefix, sufix, data, frob_err, bias):
    graphs_file_name = f'{prefix}vardim_graphs_{sufix}.pkl'
    with open(graphs_file_name, 'wb') as f:
        pickle.dump(data, f)
        print('GRAPHS SAVED AS:', graphs_file_name)
    
    perfs_file_name = f'{prefix}vardim_perf_{sufix}'
    np.savez(perfs_file_name, frob_err=frob_err, f1_score=f1_score,
             sqrt_bias=bias)
    print('PERFORMANCE SAVED AS:', perfs_file_name)

    mean_frob_err = np.mean(frob_err, axis=0)
    mean_sqrt_bias = np.mean(bias, axis=0)
    err_bias_csv_file_name = f'{PATH}vardim_{sufix}_err_bias.csv'
    error_bias_to_csv(err_bias_csv_file_name,  data['Exps'], mean_sqrt_bias, mean_frob_err)

    mean_time = np.mean(data['runingtimes'], axis=0)
    time_csv_file_name = f'{PATH}vardim_{sufix}_time.csv'
    error_to_csv(time_csv_file_name, data['Exps'], data['DIM_RANGE'], mean_time)
    print('BIAS CSV SAVED AS:', time_csv_file_name)

# %%
# Experiment params
num_trials =  50

# Graph parameters
data_p = {
    'mean_deg': 5,
    'weighted_edges': True,
    'w_range': (.5, 1),
    'psd_fact': .1,
    'group_prop': [.25, .75],
}

DIM_RANGE = [50, 100, 150, 200, 300, 500, 1000]
num_params = len(DIM_RANGE)
verbose = False

# %% [markdown]
# ## Experiment 1 - Swept on Mu2

# %%
PREC_TYPE = None

Exps = [
    {'model': 'glasso', 'args': {'alpha': .1, 'max_iter': 2000, 'tol': 1e-4}, 'fmt': 'v:', 'leg': 'GL'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 0, 'bias_type': 'dp', 
     'prec_type': PREC_TYPE, 'EARLY_STOP': True}, 'fmt': 'o:', 'leg': 'FGL-0'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 1, 'bias_type': 'dp', 
     'prec_type': PREC_TYPE, 'EARLY_STOP': True}, 'fmt': 'o--', 'leg': 'FGL-DP-1'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 1, 'bias_type': 'nodewise', 
     'prec_type': PREC_TYPE, 'EARLY_STOP': True}, 'fmt': 's--', 'leg': 'FGL-NDP-1'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 10, 'bias_type': 'dp', 
     'prec_type': PREC_TYPE, 'EARLY_STOP': True}, 'fmt': 'o-', 'leg': 'FGL-DP-10'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 10, 'bias_type': 'nodewise', 
     'prec_type': PREC_TYPE, 'EARLY_STOP': True}, 'fmt': 's-', 'leg': 'FGL-NDP-10'},

]

print('CPUs employed:', N_CPUS)
t_init = perf_counter()
results = Parallel(n_jobs=N_CPUS)(delayed(run_exp)
                                  (g, DIM_RANGE, data_p, Exps, verb=verbose) for g in range(num_trials))
ellapsed_t = (perf_counter()-t_init)/60
print(f'----- Solved in {ellapsed_t:.3f} minutes -----')


Thetas_est, Thetas_true, runingtimes, Zs = zip(*results)

# %% [markdown]
# ### Save reulst and compute errors

# %%
frob_err = compute_metric_err(Thetas_est, Thetas_true, len(Exps), Zs=None, thr=.2, metric_type='err-v2')
sqrt_bias = compute_metric_err(Thetas_est, Thetas_true, len(Exps), Zs=Zs, thr=.2, metric_type='sqrt-bias')

if SAVE:
    data = {
        'Exps': Exps,
        'DIM_RANGE': DIM_RANGE,
        'Thetas_est': Thetas_est, 
        'Thetas_true': Thetas_true,
        'runingtimes': runingtimes,
        'Zs': Zs,
    }
    save_files(PATH, 'mu2vals', data, frob_err, sqrt_bias)

# %% [markdown]
# ### Plot results

# %%
# Including bias from true graph
true_bias = compute_metric_err(Thetas_true, Thetas_true, 1, Zs=Zs, thr=.2, metric_type='bias')
true_sqrt_bias = compute_metric_err(Thetas_true, Thetas_true, 1, Zs=Zs, thr=.2, metric_type='sqrt-bias')
true_exp = {'fmt': '*:', 'leg': 'True Graph'}
Exps_aux =  Exps + [true_exp]
sqrt_bias_aux = np.concatenate((sqrt_bias, true_bias), axis=2)

plt_args = { 'linewidth': 2 }
plot_results(DIM_RANGE, frob_err, Exps, y_label='Error', plt_args=plt_args, save=SAVE,
             file_name=f'{PATH}vardim_mu2vals_plt_err')
plot_results(DIM_RANGE, sqrt_bias_aux, Exps_aux, y_label='Sqrt Bias', plt_args=plt_args, plot_f='loglog', 
             save=SAVE, file_name=f'{PATH}vardim_mu2vals_plt_sqrtbias')
plot_err_bias_results(frob_err, sqrt_bias, Exps, plot_lines=True, y_label='Sqrt Bias',save=SAVE,
                      file_name=f'{PATH}vardim_mu2vals_plt_err-sqrtbias')
plot_results(DIM_RANGE, runingtimes, Exps, y_label='Time', plt_args=plt_args, plot_f='loglog',
             save=SAVE, file_name=f'{PATH}vardim_mu2vals_plt_time')
# Out:
# Fig save as: ./results/vardim/vardim_mu2vals_plt_err
# Fig save as: ./results/vardim/vardim_mu2vals_plt_sqrtbias
# Fig save as: ./results/vardim/vardim_mu2vals_plt_err-sqrtbias
# Fig save as: ./results/vardim/vardim_mu2vals_plt_time

# %%
# # Load data
# file_name = PATH + 'vardim_graphs_mu2vals.pkl'
# with open(file_name, 'rb') as f:
#     data = pickle.load(f)

# Exps = data['Exps']
# Thetas_est = data['Thetas_est']
# Thetas_true = data['Thetas_true']
# runingtimes = data['runingtimes']
# Zs = data['Zs']

# %% [markdown]
# ## Experiment 2 - Nonnegative projection

# %%
Exps = [
    # Unfair models
    {'model': 'glasso', 'args': {'alpha': .1, 'max_iter': 2000, 'tol': 1e-4}, 'fmt': 'v:', 'leg': 'GL'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 0, 'bias_type': 'dp', 
     'prec_type': None, 'EARLY_STOP': True}, 'fmt': 'o:', 'leg': 'GL'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 5, 'bias_type': 'dp', 
     'prec_type': None, 'EARLY_STOP': True}, 'fmt': 'o-', 'leg': 'FGL DP'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 5, 'bias_type': 'nodewise', 
     'prec_type': None, 'EARLY_STOP': True}, 'fmt': 'o--', 'leg': 'FGL NDP'},

    
    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 0, 'bias_type': 'dp', 
     'prec_type': 'non-negative', 'EARLY_STOP': True}, 'fmt': 's:', 'leg': 'GL Proj'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 5, 'bias_type': 'dp', 
     'prec_type': 'non-negative', 'EARLY_STOP': True}, 'fmt': 's-', 'leg': 'FGL DP Proj'},

    {'model': 'fair_flasso', 'args': {'mu1': .1, 'eta': 5e-3, 'mu2': 5, 'bias_type': 'nodewise', 
     'prec_type': 'non-negative', 'EARLY_STOP': True}, 'fmt': 's--', 'leg': 'FGL NDP Proj'},
]

print('CPUs employed:', N_CPUS)
t_init = perf_counter()
results = Parallel(n_jobs=N_CPUS)(delayed(run_exp)
                                  (g, DIM_RANGE, data_p, Exps, verb=verbose) for g in range(num_trials))
t_end = perf_counter()
print(f'----- Solved in {t_end-t_init:.3f} seconds -----')


Thetas_est, Thetas_true, runingtimes, Zs = zip(*results)
# Out:
# CPUs employed: 64
# Graph 1 Number of nodes: 50
# Graph 1 Number of nodes: 100
# Graph 2 Number of nodes: 50
# Graph 3 Number of nodes: 50
# Graph 4 Number of nodes: 50
# Graph 5 Number of nodes: 50
# Graph 6 Number of nodes: 50
# Graph 12 Number of nodes: 50
# Graph 7 Number of nodes: 50
# Graph 15 Number of nodes: 50
# Graph 19 Number of nodes: 50
# Graph 23 Number of nodes: 50
# Graph 21 Number of nodes: 50
# Graph 9 Number of nodes: 50
# Graph 10 Number of nodes: 50
# Graph 13 Number of nodes: 50
# Graph 30 Number of nodes: 50
# Graph 20 Number of nodes: 50
# Graph 27 Number of nodes: 50
# Graph 17 Number of nodes: 50
# Graph 8 Number of nodes: 50
# Graph 22 Number of nodes: 50
# Graph 16 Number of nodes: 50
# Graph 25 Number of nodes: 50
# Graph 18 Number of nodes: 50
# Graph 31 Number of nodes: 50
# Graph 11 Number of nodes: 50
# Graph 34 Number of nodes: 50
# Graph 26 Number of nodes: 50
# Graph 14 Number of nodes: 50
# Graph 38 Number of nodes: 50
# Graph 24 Number of nodes: 50
# Graph 29 Number of nodes: 50
# Graph 39 Number of nodes: 50
# Graph 33 Number of nodes: 50
# Graph 28 Number of nodes: 50
# Graph 40 Number of nodes: 50
# Graph 32 Number of nodes: 50
# Graph 37 Number of nodes: 50
# Graph 36 Number of nodes: 50
# Graph 35 Number of nodes: 50
# Graph 42 Number of nodes: 50
# Graph 41 Number of nodes: 50
# Graph 43 Number of nodes: 50
# Graph 49 Number of nodes: 50
# Graph 48 Number of nodes: 50
# Graph 50 Number of nodes: 50
# Graph 46 Number of nodes: 50
# Graph 47 Number of nodes: 50
# Graph 45 Number of nodes: 50
# Graph 44 Number of nodes: 50
# Graph 2 Number of nodes: 100
# Graph 3 Number of nodes: 100
# Graph 5 Number of nodes: 100
# Graph 6 Number of nodes: 100
# Graph 26 Number of nodes: 100
# Graph 23 Number of nodes: 100
# Graph 22 Number of nodes: 100
# Graph 43 Number of nodes: 100
# Graph 30 Number of nodes: 100
# Graph 15 Number of nodes: 100
# Graph 45 Number of nodes: 100
# Graph 17 Number of nodes: 100
# Graph 21 Number of nodes: 100
# Graph 16 Number of nodes: 100
# Graph 20 Number of nodes: 100
# Graph 8 Number of nodes: 100
# Graph 25 Number of nodes: 100
# Graph 27 Number of nodes: 100
# Graph 29 Number of nodes: 100
# Graph 34 Number of nodes: 100
# Graph 18 Number of nodes: 100
# Graph 9 Number of nodes: 100
# Graph 14 Number of nodes: 100
# Graph 39 Number of nodes: 100
# Graph 40 Number of nodes: 100
# Graph 19 Number of nodes: 100
# Graph 41 Number of nodes: 100
# Graph 49 Number of nodes: 100
# Graph 24 Number of nodes: 100
# Graph 42 Number of nodes: 100
# Graph 48 Number of nodes: 100
# Graph 11 Number of nodes: 100
# Graph 32 Number of nodes: 100
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.722e-03
#   warnings.warn(
# Graph 46 Number of nodes: 100
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.944e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.768e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.712e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.701e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.201e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.588e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.416e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.829e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.006e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.352e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: -3.561e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.626e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.056e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.627e-03
#   warnings.warn(
# Graph 1 Number of nodes: 150
# Graph 4 Number of nodes: 100
# Graph 47 Number of nodes: 100
# Graph 12 Number of nodes: 100
# Graph 13 Number of nodes: 100
# Graph 33 Number of nodes: 100
# Graph 37 Number of nodes: 100
# Graph 38 Number of nodes: 100
# Graph 50 Number of nodes: 100
# Graph 28 Number of nodes: 100
# Graph 35 Number of nodes: 100
# Graph 7 Number of nodes: 100
# Graph 10 Number of nodes: 100
# Graph 31 Number of nodes: 100
# Graph 36 Number of nodes: 100
# Graph 44 Number of nodes: 100
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.329e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.557e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.378e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.050e-03
#   warnings.warn(
# Graph 43 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.695e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.332e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.146e-03
#   warnings.warn(
# Graph 22 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.848e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.957e-03
#   warnings.warn(
# Graph 23 Number of nodes: 150
# Graph 17 Number of nodes: 150
# Graph 15 Number of nodes: 150
# Graph 27 Number of nodes: 150
# Graph 40 Number of nodes: 150
# Graph 8 Number of nodes: 150
# Graph 42 Number of nodes: 150
# Graph 11 Number of nodes: 150
# Graph 41 Number of nodes: 150
# Graph 14 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.149e-02
#   warnings.warn(
# Graph 20 Number of nodes: 150
# Graph 29 Number of nodes: 150
# Graph 32 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.533e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.145e-03
#   warnings.warn(
# Graph 46 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.226e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.915e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.771e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.795e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.804e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.127e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.871e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.853e-03
#   warnings.warn(
# Graph 12 Number of nodes: 150
# Graph 28 Number of nodes: 150
# Graph 37 Number of nodes: 150
# Graph 5 Number of nodes: 150
# Graph 38 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.008e-03
#   warnings.warn(
# Graph 4 Number of nodes: 150
# Graph 33 Number of nodes: 150
# Graph 10 Number of nodes: 150
# Graph 31 Number of nodes: 150
# Graph 7 Number of nodes: 150
# Graph 36 Number of nodes: 150
# Graph 44 Number of nodes: 150
# Graph 2 Number of nodes: 150
# Graph 26 Number of nodes: 150
# Graph 45 Number of nodes: 150
# Graph 3 Number of nodes: 150
# Graph 34 Number of nodes: 150
# Graph 18 Number of nodes: 150
# Graph 6 Number of nodes: 150
# Graph 30 Number of nodes: 150
# Graph 49 Number of nodes: 150
# Graph 9 Number of nodes: 150
# Graph 24 Number of nodes: 150
# Graph 48 Number of nodes: 150
# Graph 25 Number of nodes: 150
# Graph 16 Number of nodes: 150
# Graph 21 Number of nodes: 150
# Graph 39 Number of nodes: 150
# Graph 19 Number of nodes: 150
# Graph 47 Number of nodes: 150
# Graph 50 Number of nodes: 150
# Graph 13 Number of nodes: 150
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.546e-03
#   warnings.warn(
# Graph 35 Number of nodes: 150
# Graph 1 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.559e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.669e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.027e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.364e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.014e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.217e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.452e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.302e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.907e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.961e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.941e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.977e-03
#   warnings.warn(
# Graph 11 Number of nodes: 200
# Graph 22 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.186e-02
#   warnings.warn(
# Graph 27 Number of nodes: 200
# Graph 20 Number of nodes: 200
# Graph 8 Number of nodes: 200
# Graph 32 Number of nodes: 200
# Graph 46 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.890e-03
#   warnings.warn(
# Graph 23 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.935e-03
#   warnings.warn(
# Graph 37 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.148e-03
#   warnings.warn(
# Graph 2 Number of nodes: 200
# Graph 12 Number of nodes: 200
# Graph 10 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.719e-03
#   warnings.warn(
# Graph 5 Number of nodes: 200
# Graph 33 Number of nodes: 200
# Graph 7 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.931e-03
#   warnings.warn(
# Graph 36 Number of nodes: 200
# Graph 38 Number of nodes: 200
# Graph 34 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.958e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.409e-03
#   warnings.warn(
# Graph 18 Number of nodes: 200
# Graph 30 Number of nodes: 200
# Graph 39 Number of nodes: 200
# Graph 19 Number of nodes: 200
# Graph 49 Number of nodes: 200
# Graph 43 Number of nodes: 200
# Graph 9 Number of nodes: 200
# Graph 24 Number of nodes: 200
# Graph 25 Number of nodes: 200
# Graph 47 Number of nodes: 200
# Graph 35 Number of nodes: 200
# Graph 41 Number of nodes: 200
# Graph 40 Number of nodes: 200
# Graph 17 Number of nodes: 200
# Graph 14 Number of nodes: 200
# Graph 42 Number of nodes: 200
# Graph 29 Number of nodes: 200
# Graph 4 Number of nodes: 200
# Graph 31 Number of nodes: 200
# Graph 15 Number of nodes: 200
# Graph 28 Number of nodes: 200
# Graph 44 Number of nodes: 200
# Graph 26 Number of nodes: 200
# Graph 45 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.225e-03
#   warnings.warn(
# Graph 6 Number of nodes: 200
# Graph 3 Number of nodes: 200
# Graph 50 Number of nodes: 200
# Graph 48 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.694e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.054e-02
#   warnings.warn(
# Graph 21 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.847e-03
#   warnings.warn(
# Graph 13 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.234e-03
#   warnings.warn(
# Graph 16 Number of nodes: 200
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.721e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.885e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.382e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.008e-02
#   warnings.warn(
# Graph 1 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.204e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.528e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.746e-03
#   warnings.warn(
# Graph 22 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.727e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.065e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.323e-03
#   warnings.warn(
# Graph 27 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.376e-03
#   warnings.warn(
# Graph 2 Number of nodes: 300
# Graph 20 Number of nodes: 300
# Graph 23 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.186e-03
#   warnings.warn(
# Graph 5 Number of nodes: 300
# Graph 34 Number of nodes: 300
# Graph 33 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.830e-03
#   warnings.warn(
# Graph 36 Number of nodes: 300
# Graph 43 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.580e-03
#   warnings.warn(
# Graph 7 Number of nodes: 300
# Graph 49 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.215e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.170e-02
#   warnings.warn(
# Graph 19 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.111e-02
#   warnings.warn(
# Graph 24 Number of nodes: 300
# Graph 25 Number of nodes: 300
# Graph 47 Number of nodes: 300
# Graph 41 Number of nodes: 300
# Graph 35 Number of nodes: 300
# Graph 18 Number of nodes: 300
# Graph 31 Number of nodes: 300
# Graph 28 Number of nodes: 300
# Graph 44 Number of nodes: 300
# Graph 11 Number of nodes: 300
# Graph 45 Number of nodes: 300
# Graph 42 Number of nodes: 300
# Graph 3 Number of nodes: 300
# Graph 12 Number of nodes: 300
# Graph 8 Number of nodes: 300
# Graph 46 Number of nodes: 300
# Graph 10 Number of nodes: 300
# Graph 32 Number of nodes: 300
# Graph 21 Number of nodes: 300
# Graph 37 Number of nodes: 300
# Graph 16 Number of nodes: 300
# Graph 30 Number of nodes: 300
# Graph 39 Number of nodes: 300
# Graph 38 Number of nodes: 300
# Graph 9 Number of nodes: 300
# Graph 4 Number of nodes: 300
# Graph 17 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.031e-03
#   warnings.warn(
# Graph 14 Number of nodes: 300
# Graph 29 Number of nodes: 300
# Graph 40 Number of nodes: 300
# Graph 15 Number of nodes: 300
# Graph 26 Number of nodes: 300
# Graph 6 Number of nodes: 300
# Graph 50 Number of nodes: 300
# Graph 13 Number of nodes: 300
# Graph 48 Number of nodes: 300
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.063e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.116e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.301e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.133e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.930e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.473e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.260e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.223e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.001e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.451e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.354e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.865e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.065e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.169e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.802e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.125e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.869e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.292e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.415e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.646e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.745e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.068e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.956e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.689e-03
#   warnings.warn(
# Graph 27 Number of nodes: 500
# Graph 22 Number of nodes: 500
# Graph 20 Number of nodes: 500
# Graph 34 Number of nodes: 500
# Graph 5 Number of nodes: 500
# Graph 44 Number of nodes: 500
# Graph 49 Number of nodes: 500
# Graph 28 Number of nodes: 500
# Graph 3 Number of nodes: 500
# Graph 2 Number of nodes: 500
# Graph 41 Number of nodes: 500
# Graph 7 Number of nodes: 500
# Graph 11 Number of nodes: 500
# Graph 35 Number of nodes: 500
# Graph 19 Number of nodes: 500
# Graph 45 Number of nodes: 500
# Graph 48 Number of nodes: 500
# Graph 1 Number of nodes: 500
# Graph 39 Number of nodes: 500
# Graph 47 Number of nodes: 500
# Graph 17 Number of nodes: 500
# Graph 6 Number of nodes: 500
# Graph 9 Number of nodes: 500
# Graph 24 Number of nodes: 500
# Graph 37 Number of nodes: 500
# Graph 13 Number of nodes: 500
# Graph 31 Number of nodes: 500
# Graph 8 Number of nodes: 500
# Graph 4 Number of nodes: 500
# Graph 46 Number of nodes: 500
# Graph 33 Number of nodes: 500
# Graph 10 Number of nodes: 500
# Graph 18 Number of nodes: 500
# Graph 43 Number of nodes: 500
# Graph 21 Number of nodes: 500
# Graph 36 Number of nodes: 500
# Graph 23 Number of nodes: 500
# Graph 50 Number of nodes: 500
# Graph 42 Number of nodes: 500
# Graph 14 Number of nodes: 500
# Graph 15 Number of nodes: 500
# Graph 38 Number of nodes: 500
# Graph 12 Number of nodes: 500
# Graph 25 Number of nodes: 500
# Graph 29 Number of nodes: 500
# Graph 40 Number of nodes: 500
# Graph 30 Number of nodes: 500
# Graph 32 Number of nodes: 500
# Graph 26 Number of nodes: 500
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.229e-02
#   warnings.warn(
# Graph 16 Number of nodes: 500
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.103e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.906e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.329e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.273e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.898e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.518e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.129e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.929e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.824e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.730e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.438e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.142e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.220e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.291e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.998e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.802e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.236e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.102e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.919e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.933e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 7.845e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.601e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.666e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.465e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.139e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.823e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.047e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.137e-02
#   warnings.warn(
# Graph 34 Number of nodes: 1000
# Graph 2 Number of nodes: 1000
# Graph 8 Number of nodes: 1000
# Graph 24 Number of nodes: 1000
# Graph 22 Number of nodes: 1000
# Graph 49 Number of nodes: 1000
# Graph 3 Number of nodes: 1000
# Graph 48 Number of nodes: 1000
# Graph 28 Number of nodes: 1000
# Graph 14 Number of nodes: 1000
# Graph 1 Number of nodes: 1000
# Graph 9 Number of nodes: 1000
# Graph 27 Number of nodes: 1000
# Graph 41 Number of nodes: 1000
# Graph 7 Number of nodes: 1000
# Graph 33 Number of nodes: 1000
# Graph 15 Number of nodes: 1000
# Graph 37 Number of nodes: 1000
# Graph 20 Number of nodes: 1000
# Graph 36 Number of nodes: 1000
# Graph 35 Number of nodes: 1000
# Graph 17 Number of nodes: 1000
# Graph 11 Number of nodes: 1000
# Graph 47 Number of nodes: 1000
# Graph 44 Number of nodes: 1000
# Graph 10 Number of nodes: 1000
# Graph 50 Number of nodes: 1000
# Graph 6 Number of nodes: 1000
# Graph 39 Number of nodes: 1000
# Graph 18 Number of nodes: 1000
# Graph 45 Number of nodes: 1000
# Graph 23 Number of nodes: 1000
# Graph 40 Number of nodes: 1000
# Graph 4 Number of nodes: 1000
# Graph 43 Number of nodes: 1000
# Graph 21 Number of nodes: 1000
# Graph 5 Number of nodes: 1000
# Graph 13 Number of nodes: 1000
# Graph 12 Number of nodes: 1000
# Graph 46 Number of nodes: 1000
# Graph 25 Number of nodes: 1000
# Graph 16 Number of nodes: 1000
# Graph 19 Number of nodes: 1000
# Graph 31 Number of nodes: 1000
# Graph 30 Number of nodes: 1000
# Graph 26 Number of nodes: 1000
# Graph 38 Number of nodes: 1000
# Graph 32 Number of nodes: 1000
# Graph 42 Number of nodes: 1000
# Graph 29 Number of nodes: 1000
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.185e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.835e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.254e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.177e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.228e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.608e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.518e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.031e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.021e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.374e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.159e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.295e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.066e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 4.796e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.855e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.107e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 2.213e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 9.845e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.074e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 6.145e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.994e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.181e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.744e-02
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 5.171e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 8.269e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 3.118e-03
#   warnings.warn(
# /home/srey/Investigacion/fair_GL/.venv/lib/python3.10/site-packages/sklearn/covariance/_graph_lasso.py:184: ConvergenceWarning: graphical_lasso: did not converge after 1000 iteration: dual gap: 1.240e-02
#   warnings.warn(
# ----- Solved in 32084.230 seconds -----

# %% [markdown]
# ### Save reulst and compute errors

# %%
frob_err = compute_metric_err(Thetas_est, Thetas_true, len(Exps), Zs=None, thr=.2, metric_type='err-v2')
sqrt_bias = compute_metric_err(Thetas_est, Thetas_true, len(Exps), Zs=Zs, thr=.2, metric_type='sqrt-bias')

if SAVE:
    file_name = PATH + f'vardim_graphs_proj.pkl'
    data = {
        'Exps': Exps,
        'DIM_RANGE': DIM_RANGE,
        'Thetas_est': Thetas_est, 
        'Thetas_true': Thetas_true,
        'runingtimes': runingtimes,
        'Zs': Zs,
    }
    save_files(PATH, 'proj', data, frob_err, sqrt_bias)
# Out:
# DATA SAVED AS: ./results/vardim/vardim_graphs_proj.pkl
# PERFORMANCE SAVED AS: ./results/vardim/vardim_perf_proj

# %% [markdown]
# ### Plot results

# %%
# Including bias from true graph
true_bias = compute_metric_err(Thetas_true, Thetas_true, 1, Zs=Zs, thr=.2, metric_type='bias')
true_sqrt_bias = compute_metric_err(Thetas_true, Thetas_true, 1, Zs=Zs, thr=.2, metric_type='sqrt-bias')
true_exp = {'fmt': '*:', 'leg': 'True Graph'}
Exps_aux =  Exps + [true_exp]
bias_aux = np.concatenate((bias, true_bias), axis=2)
sqrt_bias_aux = np.concatenate((sqrt_bias, true_bias), axis=2)

plt_args = { 'linewidth': 2 }
plot_results(DIM_RANGE, frob_err, Exps, y_label='Error', plt_args=plt_args, save=SAVE,
             file_name=f'{PATH}vardim_proj_plt_err')
plot_results(DIM_RANGE, sqrt_bias_aux, Exps_aux, y_label='Sqrt Bias', plt_args=plt_args, plot_f='loglog', 
             save=SAVE, file_name=f'{PATH}vardim_proj_plt_sqrtbias')
plot_err_bias_results(frob_err, sqrt_bias, Exps, plot_lines=True, y_label='Sqrt Bias', save=SAVE,
                      file_name=f'{PATH}vardim_proj_plt_err-sqrtbias')

plot_results(DIM_RANGE, bias_aux, Exps_aux, y_label='Bias', plt_args=plt_args, plot_f='loglog',
             save=SAVE, file_name=f'{PATH}vardim_proj_plt_bias')
plot_err_bias_results(frob_err, bias, Exps, plot_lines=True, save=SAVE,
                      file_name=f'{PATH}vardim_proj_plt_err-bias')

plot_results(DIM_RANGE, runingtimes, Exps, y_label='Time', plt_args=plt_args, plot_f='loglog', 
             save=SAVE, file_name=f'{PATH}vardim_proj_plt_time')
plot_results(DIM_RANGE, f1_score, Exps, y_label='F1 score', plt_args=plt_args)
# Out:
# Fig save as: ./results/vardim/vardim_proj_plt_err
# Fig save as: ./results/vardim/vardim_proj_plt_sqrtbias
# Fig save as: ./results/vardim/vardim_proj_plt_err-sqrtbias
# Fig save as: ./results/vardim/vardim_proj_plt_bias
# Fig save as: ./results/vardim/vardim_proj_plt_err-bias
# Fig save as: ./results/vardim/vardim_proj_plt_time

# %%
# # Load data
# file_name = PATH + 'vardim_graphs_v0'
# with open(file_name, 'rb') as f:
#     data = pickle.load(f)

# Exps = data['Exps']
# Thetas_est = data['Thetas_est']
# Thetas_true = data['Thetas_true']
# runingtimes = data['runingtimes']
# Zs = data['Zs']
